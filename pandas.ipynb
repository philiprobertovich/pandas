# %%
import pandas as pd

albums = pd.read_csv('data/spotify_spotify_albums.csv', header=0)
artists = pd.read_csv('data/spotify_spotify_artists.csv', header=0)
tracks = pd.read_csv('data/spotify_spotify_tracks.csv', header=0)

# %%
# This will show the first five rows of the albums dataframe and should output all the columns within the set
albums.head()

# This will show the last five rows of the albums dataframe and should output all the columns within the set
albums.tail()

# # This will show the dimensions (columns x row) of the dataframe
albums.shape
# Out:
# (75511, 16)

# %%
# Artists dataframe profiling
artists.head()
artists.tail()
artists.shape
# Out:
# (56129, 9)

# %%
# Tracks dataframe profiling
tracks.head()
tracks.tail()
tracks.shape
# Out:
# (101939, 32)

# %%
albums.loc[10:20, ['name', 'release_date']]
# Out:
#                                                  name release_date
# 10  Beethoven: 6 Bagatelles & Piano Sonatas Nos. 3...   2019-03-01
# 11                                Au Long de la Loire   2019-03-01
# 12                                     I Still Miss U   2019-03-15
# 13                                     Kolmekymppinen         1980
# 14                                              Bruja   2018-04-24
# 15                            Sonatas for two violins   2019-03-01
# 16                                            Sirènes   2019-03-01
# 17                                       Light of Day   2019-03-01
# 18                                   Madame del Campo   2015-08-03
# 19  Beethoven: Piano Concerto No. 2 & Triple Conce...   2019-03-01
# 20                                      Violinsonaten   2019-03-01

# %%
#Albums dataset cleaning
albums.duplicated()

albums.drop_duplicates

#No duplicates
#Fill all NaN values
albums.fillna('None')
# Out:
#        index album_type               artist_id  \
# 0          0     single  3DiDSECUqqY1AuBP8qtaIa
# 1          1      album  6s1pCNXcbdtQJlsnM1hRIA
# 2          2     single  5YjfNaHq05WrwldRe1QSBc
# 3          3     single  2G9Vc16JCpnZmK4uGH46Fa
# 4          4     single  2dwM9OcE4c3Ph1UBINSodx
# ...      ...        ...                     ...
# 75506  75506      album  0S7CCsKpXJ8e1dIstizHw5
# 75507  75507      album  73Vk4dL8kYkbRJxWJDq1wL
# 75508  75508      album  3yW6jTzGjHUUkLvLkjLOVn
# 75509  75509      album  4iudEcmuPlYNdbP3e1bdn1
# 75510  75510      album  023YMawCG3OvACmRjWxLWC
#
#                                        available_markets  \
# 0      ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 1      ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 2      ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 3      ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 4      ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# ...

# %%
#Artists dataset cleaning
artists.duplicated()

artists.drop_duplicates()

#No duplicates
#Fill all NaN values
artists.fillna('None')
# Out:
#        index  artist_popularity  followers  \
# 0          0                 44      23230
# 1          1                 22        313
# 2          2                 26       1596
# 3          3                 31        149
# 4          4                 21         11
# ...      ...                ...        ...
# 56124  56124                 23       1212
# 56125  56125                 42      57973
# 56126  56126                 38      20870
# 56127  56127                 44      33923
# 56128  56128                 44      42026
#
#                                                   genres  \
# 0      ['sertanejo', 'sertanejo pop', 'sertanejo trad...
# 1                                                     []
# 2                                    ['danish pop rock']
# 3                                 ['uk alternative pop']
# 4                                     ['french baroque']
# ...                                                  ...
# ...

# %%
#Tracks data cleaning
tracks.duplicated()

tracks.drop_duplicates()

#No duplicates
# Fill in NaN values
tracks.fillna('None')
# Out:
#          index  acousticness                album_id  \
# 0            0      0.294000  0D3QufeCudpQANOR7luqdr
# 1            1      0.863000  1bcqsH5UyTBzmh9YizdsBE
# 2            2      0.750000  4tKijjmxGClg4JOLAyo2qE
# 3            3      0.763000  6FeJF5r8roonnKraJxr4oB
# 4            4      0.770000  4tKijjmxGClg4JOLAyo2qE
# ...        ...           ...                     ...
# 101934  101934      0.005640  1M9n4vCmOH4lbcHrpt21Qy
# 101935  101935      0.000406  511p6iaCuK8Sr0BYdpcfkq
# 101936  101936      0.004510  511p6iaCuK8Sr0BYdpcfkq
# 101937  101937      0.333000  7H3Bgvb3hs4vvLwccHDRlr
# 101938  101938      0.028400  3oieBBYbUOve0VpxTCpHr1
#
#                                              analysis_url  \
# 0       https://api.spotify.com/v1/audio-analysis/5qlj...
# 1       https://api.spotify.com/v1/audio-analysis/3VAX...
# 2       https://api.spotify.com/v1/audio-analysis/1L3Y...
# 3       https://api.spotify.com/v1/audio-analysis/6aCe...
# ...

# %%
def swap_empty_list(value):
  if value == []:
    return 'NaN'
  else:
    return value

artists['genres'] = artists['genres'].map(swap_empty_list)

artists.genres
# Out:
# 0        ['sertanejo', 'sertanejo pop', 'sertanejo trad...
# 1                                                       []
# 2                                      ['danish pop rock']
# 3                                   ['uk alternative pop']
# 4                                       ['french baroque']
#                                ...
# 56124                                     ['chilean rock']
# 56125    ['aggro chileno', 'andean', 'chilean rock', 'l...
# 56126    ['australian alternative rock', 'australian ro...
# 56127    ['australian alternative rock', 'australian ro...
# 56128    ['australian alternative rock', 'australian in...
# Name: genres, Length: 56129, dtype: object

# %%
print(list(tracks.columns))

tracks.drop('lyrics', inplace=True, axis=1)

print(list(tracks.columns))
# Out:
# ['index', 'acousticness', 'album_id', 'analysis_url', 'artists_id', 'available_markets', 'country', 'danceability', 'disc_number', 'duration_ms', 'energy', 'href', 'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'lyrics', 'mode', 'name', 'playlist', 'popularity', 'preview_url', 'speechiness', 'tempo', 'time_signature', 'track_href', 'track_name_prev', 'track_number', 'uri', 'valence', 'type']
# ['index', 'acousticness', 'album_id', 'analysis_url', 'artists_id', 'available_markets', 'country', 'danceability', 'disc_number', 'duration_ms', 'energy', 'href', 'id', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'name', 'playlist', 'popularity', 'preview_url', 'speechiness', 'tempo', 'time_signature', 'track_href', 'track_name_prev', 'track_number', 'uri', 'valence', 'type']

# %%
# Creating the merged dataframe of the artist and albums dataframes
artists_albums_join = pd.merge(artists, albums, how='inner', left_on='id', right_on='artist_id')

# I chose an inner join, since it will show all the albums that have artists that have albums in the album dataframe.

print(artists_albums_join.head())
print(artists_albums_join.shape)
# Out:
#    index_x  artist_popularity  followers  \
# 0        0                 44      23230
# 1        0                 44      23230
# 2        1                 22        313
# 3        2                 26       1596
# 4        3                 31        149
#
#                                               genres                    id_x  \
# 0  ['sertanejo', 'sertanejo pop', 'sertanejo trad...  4mGnpjhqgx4RUdsIJiURdo
# 1  ['sertanejo', 'sertanejo pop', 'sertanejo trad...  4mGnpjhqgx4RUdsIJiURdo
# 2                                                 []  1dLnVku4VQUOLswwDFvRc9
# 3                                ['danish pop rock']  6YVY310fjfUzKi8hiqR7iK
# 4                             ['uk alternative pop']  2VElyouiCfoYPDJluzwJwK
#
#            name_x              track_id_x track_name_prev_x  type_x  index_y  \
# 0   Juliano Cezar  0wmDmAILuW9e2aRttkl4aC           track_9  artist       50
# 1   Juliano Cezar  0wmDmAILuW9e2aRttkl4aC           track_9  artist     4798
# ...

# %%
# Create the merged dataframe of the albums and tracks dataframes
albums_tracks_join = pd.merge(albums, tracks, how='inner', left_on='id', right_on='album_id')

#I chose to implement an innner join, so that the dataframe will reflect all tracks that are within an album.
print(albums_tracks_join.head())
print(albums_tracks_join.shape)
# Out:
#    index_x album_type               artist_id  \
# 0        0     single  3DiDSECUqqY1AuBP8qtaIa
# 1        1      album  6s1pCNXcbdtQJlsnM1hRIA
# 2        2     single  5YjfNaHq05WrwldRe1QSBc
# 3        3     single  2G9Vc16JCpnZmK4uGH46Fa
# 4        4     single  2dwM9OcE4c3Ph1UBINSodx
#
#                                  available_markets_x  \
# 0  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 1  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 2  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 3  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 4  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/1g...
# 1  {'spotify': 'https://open.spotify.com/album/4K...
# 2  {'spotify': 'https://open.spotify.com/album/7n...
# 3  {'spotify': 'https://open.spotify.com/album/6p...
# 4  {'spotify': 'https://open.spotify.com/album/1X...
#
# ...

# %%
artists.describe()

# Ariana Grande is the most popular artist in the dataframe
artists[artists.artist_popularity == 100]

# Shows top 10 popular artists
artists.sort_values(by='artist_popularity', ascending=False).head(10)
# Out:
#        index  artist_popularity  followers  \
# 42872  42872                100   26309771
# 53392  53392                 98   34680740
# 49775  49775                 96   12150628
# 55822  55822                 95   11564320
# 49695  49695                 95    3607186
# 53406  53406                 95    5476601
# 52306  52306                 95   15389549
# 55502  55502                 94   11616538
# 49320  49320                 94    5097861
# 39126  39126                 94   14130233
#
#                                                   genres  \
# 42872              ['dance pop', 'pop', 'post-teen pop']
# 53392  ['canadian hip hop', 'canadian pop', 'hip hop'...
# 49775                                     ['pop', 'rap']
# 55822                       ['emo rap', 'miami hip hop']
# 49695                                    ['chicago rap']
# 53406                                            ['pop']
# 52306                       ['reggaeton', 'trap latino']
# ...

# %%
#Haze and Sasha appear the most within the Artist dataframe
artist_freq = artists['name'].value_counts()
artist_freq
# Out:
# Haze                  5
# Sasha                 5
# Elias                 4
# Karina                4
# Alex                  4
#                      ..
# Steuerfreimoney       1
# Avery Florence        1
# Ian van Dahl          1
# Bikini Kill           1
# Something For Kate    1
# Name: name, Length: 55505, dtype: int64
